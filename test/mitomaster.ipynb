# %%
# !hostname
# Out:
# m-4-02

# %%
# !which python
# Out:
# ~/tools/anaconda3/bin/python

# %%
import requests

# %%
# !pwd
# Out:
# /home/liuc9

# %%
try:
    response = requests.post("https://mitomap.org/mitomaster/websrvc.cgi", files={"file": open("/home/liuc9/github/scRNAseq-MitoVariant/test/snvlist.tsv"), "fileType": ("", "snvlist"), "output": ("", "detail")})
    print(str(response.content, "utf-8"))
except requests.exceptions.HTTPError as err:
    print("HTTP error: " + err)
except:
    print("Error")
# Out:
# query	tpos	qpos	tnt	qnt	ntchange	allele	calc_locus	calc_aachange	conservation	haplogroup	verbose_haplogroup	patientphenotype	mmutid	rtmutid	polyid	subvar_cnt	is_polymorphism	is_mmut	is_rtmut	is_submitted	gb_cnt	gb_perc	hap_cnt	hap_perc
# Sample1	73	0	A	G	transition		CR:HVS2<br>ATT<br>CR:Control Region<br>CR:7S-like	non-coding			n/a low homology		0	0	14	0	true	false	false	false	44589	75.080	0	0.000
# Sample1	146	0	T	C	transition	m.146T>C	CR:HVS2<br>CR:OH<br>ATT<br>CR:Control Region<br>CR:7S-like	non-coding			n/a low homology	Absence of Endometriosis	355	0	33	0	true	true	false	false	11290	19.010	0	0.000
